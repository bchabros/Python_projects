# %% [markdown]
# ## Import Bibliotek

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,plot_confusion_matrix,accuracy_score

from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Activation, Dense
from tensorflow.keras.layers import Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ## Wczytanie danych

# %%
(X_train, y_train), (X_t, y_t) = fashion_mnist.load_data()

# %%
X_val, X_test, y_val, y_test = train_test_split(X_t, y_t, test_size=0.5)
print(f'zbior treningowy: {X_train.shape}, zbior walidacyjny: {X_val.shape}, zbior testowy: {X_test.shape}')
# Out:
# zbior treningowy: (60000, 28, 28), zbior walidacyjny: (5000, 28, 28), zbior testowy: (5000, 28, 28)

# %%
plt.figure(figsize=(7, 7))
plt.imshow(X_train[7],
           cmap=plt.cm.binary)
plt.colorbar()
plt.show()

# %%
# wykres dla kazdego pixela
def plot_digit(digit, dem=28, font_size=8):
    max_ax = font_size * dem
    
    fig = plt.figure(figsize=(10, 10))
    plt.xlim([0, max_ax])
    plt.ylim([0, max_ax])
    plt.axis('off')
    
    for idx in range(dem):
        for jdx in range(dem):
            t = plt.text(idx*font_size,
                         max_ax - jdx*font_size,
                         digit[jdx][idx],
                         fontsize=font_size,
                         color='#000000')
            c = digit[jdx][idx] / 255.
            t.set_bbox(dict(facecolor=(c, c, c),
                            alpha=0.5,
                            edgecolor='#f1f1f1'))
    plt.show()
plot_digit(X_train[7])

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(14, 10))
for i in range(40):
    plt.subplot(5, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], 
               cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## Przygotowanie danych

# %%
X_train = X_train.astype('float32') / 255.0
X_val = X_val.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
y_train = to_categorical(y_train, len(class_names))
y_val = to_categorical(y_val, len(class_names))
y_test = to_categorical(y_test, len(class_names))

# %% [markdown]
# ## Pierwsza architektura

# %%
model = Sequential()

model.add(Flatten(input_shape=(28, 28)))

model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=10,
                    verbose=1,
                    batch_size=256,
                    validation_data = (X_val, y_val))
# Out:
# Train on 60000 samples, validate on 5000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.6218 - accuracy: 0.7899 - val_loss: 0.4943 - val_accuracy: 0.8282
# Epoch 2/10
# 60000/60000 [==============================] - 2s 42us/sample - loss: 0.4269 - accuracy: 0.8524 - val_loss: 0.4546 - val_accuracy: 0.8402
# Epoch 3/10
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.3882 - accuracy: 0.8646 - val_loss: 0.4200 - val_accuracy: 0.8544
# Epoch 4/10
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.3588 - accuracy: 0.8741 - val_loss: 0.4298 - val_accuracy: 0.8500
# Epoch 5/10
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.3433 - accuracy: 0.8789 - val_loss: 0.3911 - val_accuracy: 0.8600
# Epoch 6/10
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.3236 - accuracy: 0.8842 - val_loss: 0.4099 - val_accuracy: 0.8576
# Epoch 7/10
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.3132 - accuracy: 0.8878 - val_loss: 0.3689 - val_accuracy: 0.8700
# Epoch 8/10
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.2980 - accuracy: 0.8930 - val_loss: 0.3601 - val_accuracy: 0.8708
# Epoch 9/10
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.2912 - accuracy: 0.8948 - val_loss: 0.3726 - val_accuracy: 0.8688
# Epoch 10/10
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.2824 - accuracy: 0.8980 - val_loss: 0.3538 - val_accuracy: 0.8704

# %% [markdown]
# ## Wizualizacja

# %%
def draw_curves(history, key1='accuracy', ylim1=(0.8, 1.00), key2='loss', ylim2=(0.0, 1.0)):
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history[key1], 'r--')
    plt.plot(history.history['val_' + key1], 'g--')
    plt.ylabel(key1)
    plt.xlabel('Epoch')
    plt.ylim(ylim1)
    plt.legend(['train', 'val'], loc='best')
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history[key2], 'r--')
    plt.plot(history.history['val_' + key2], 'g--')
    plt.ylabel(key2)
    plt.xlabel('Epoch')
    plt.ylim(ylim2)
    plt.legend(['train', 'val'], loc='best')
    
    plt.show()

# %%
draw_curves(history, key1='accuracy', ylim1=(0.7, 0.95), key2='loss', ylim2=(0.0, 0.8))

# %%
# widać cały czas wzrost i spadek wiec można powiekszyć liczbę epochs

# %%
model2 = Sequential()

model2.add(Flatten(input_shape=(28, 28)))

model2.add(Dense(128, activation='relu'))

model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history2 = model2.fit(X_train,
                      y_train,
                      epochs=50,
                      verbose=1,
                      batch_size=256,
                      validation_data = (X_val, y_val))
# Out:
# Train on 60000 samples, validate on 5000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.6230 - accuracy: 0.7893 - val_loss: 0.4969 - val_accuracy: 0.8322
# Epoch 2/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.4286 - accuracy: 0.8538 - val_loss: 0.4790 - val_accuracy: 0.8260
# Epoch 3/50
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.3884 - accuracy: 0.8641 - val_loss: 0.4290 - val_accuracy: 0.8474
# Epoch 4/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.3620 - accuracy: 0.8724 - val_loss: 0.4080 - val_accuracy: 0.8550
# Epoch 5/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.3400 - accuracy: 0.8802 - val_loss: 0.3791 - val_accuracy: 0.8688
# Epoch 6/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.3225 - accuracy: 0.8861 - val_loss: 0.4009 - val_accuracy: 0.8622
# Epoch 7/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.3090 - accuracy: 0.8897 - val_loss: 0.3642 - val_accuracy: 0.8682
# Epoch 8/50
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.2993 - accuracy: 0.8929 - val_loss: 0.3643 - val_accuracy: 0.8734
# Epoch 9/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.2893 - accuracy: 0.8964 - val_loss: 0.3483 - val_accuracy: 0.8768
# Epoch 10/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.2820 - accuracy: 0.8990 - val_loss: 0.3696 - val_accuracy: 0.8688
# Epoch 11/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.2727 - accuracy: 0.9005 - val_loss: 0.3510 - val_accuracy: 0.8752
# Epoch 12/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.2628 - accuracy: 0.9054 - val_loss: 0.3631 - val_accuracy: 0.8694
# Epoch 13/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.2587 - accuracy: 0.9049 - val_loss: 0.3488 - val_accuracy: 0.8782
# Epoch 14/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.2522 - accuracy: 0.9092 - val_loss: 0.3413 - val_accuracy: 0.8798
# Epoch 15/50
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.2473 - accuracy: 0.9104 - val_loss: 0.3468 - val_accuracy: 0.8820
# Epoch 16/50
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.2440 - accuracy: 0.9111 - val_loss: 0.3375 - val_accuracy: 0.8872
# Epoch 17/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.2368 - accuracy: 0.9151 - val_loss: 0.3458 - val_accuracy: 0.8784
# Epoch 18/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.2307 - accuracy: 0.9167 - val_loss: 0.3306 - val_accuracy: 0.8804
# Epoch 19/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.1352 - accuracy: 0.9521 - val_loss: 0.3830 - val_accuracy: 0.8834
# Epoch 49/50
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.1338 - accuracy: 0.9525 - val_loss: 0.3659 - val_accuracy: 0.8914
# Epoch 50/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.1299 - accuracy: 0.9530 - val_loss: 0.3637 - val_accuracy: 0.8876

# %%
draw_curves(history2, key1='accuracy', ylim1=(0.7, 0.95), key2='loss', ylim2=(0.0, 0.8))

# %%
model3 = Sequential()

model3.add(Flatten(input_shape=(28, 28)))

model3.add(Dense(128, activation='relu', 
                 kernel_regularizer=regularizers.l2(0.01)))
model3.add(Dropout(0.2))

model3.add(Dense(10, activation='softmax'))

# %%
EarlyStop = EarlyStopping(monitor='val_loss',
                          patience=3,
                          verbose=1)

# %%
model3.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
history3 = model3.fit(X_train,
                      y_train,
                      epochs=50,
                      verbose=1,
                      batch_size=256,
                      validation_data = (X_val, y_val),
                      callbacks = [EarlyStop])
# Out:
# Train on 60000 samples, validate on 5000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 4s 60us/sample - loss: 1.3893 - accuracy: 0.7585 - val_loss: 0.7574 - val_accuracy: 0.8122
# Epoch 2/50
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.6795 - accuracy: 0.8181 - val_loss: 0.6513 - val_accuracy: 0.8124
# Epoch 3/50
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.6178 - accuracy: 0.8238 - val_loss: 0.5964 - val_accuracy: 0.8262
# Epoch 4/50
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5957 - accuracy: 0.8250 - val_loss: 0.6002 - val_accuracy: 0.8250
# Epoch 5/50
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.5829 - accuracy: 0.8294 - val_loss: 0.6190 - val_accuracy: 0.8138
# Epoch 6/50
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.5692 - accuracy: 0.8327 - val_loss: 0.5855 - val_accuracy: 0.8206
# Epoch 7/50
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.5561 - accuracy: 0.8361 - val_loss: 0.5644 - val_accuracy: 0.8326
# Epoch 8/50
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.5468 - accuracy: 0.8383 - val_loss: 0.5514 - val_accuracy: 0.8324
# Epoch 9/50
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.5444 - accuracy: 0.8389 - val_loss: 0.5507 - val_accuracy: 0.8406
# Epoch 10/50
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5475 - accuracy: 0.8371 - val_loss: 0.5658 - val_accuracy: 0.8276
# Epoch 11/50
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5380 - accuracy: 0.8413 - val_loss: 0.5720 - val_accuracy: 0.8278
# Epoch 12/50
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5364 - accuracy: 0.8416 - val_loss: 0.5537 - val_accuracy: 0.8304
# Epoch 00012: early stopping

# %%
draw_curves(history3, key1='accuracy', ylim1=(0.7, 0.95), key2='loss', ylim2=(0.0, 0.8))

# %%
model_check = ModelCheckpoint(filepath='Najlepszy model',
                              monitor='var_loss',
                              save_best_only=True)

# %%
history3 = model3.fit(X_train,
                      y_train,
                      epochs=50,
                      verbose=1,
                      batch_size=256,
                      validation_data = (X_val, y_val),
                      callbacks = [EarlyStop, model_check])
# Out:
# Train on 60000 samples, validate on 5000 samples
# Epoch 1/50
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.5297 - accuracy: 0.8416WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5303 - accuracy: 0.8413 - val_loss: 0.5378 - val_accuracy: 0.8412
# Epoch 2/50
# 59136/60000 [============================>.] - ETA: 0s - loss: 0.5265 - accuracy: 0.8432WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.5261 - accuracy: 0.8432 - val_loss: 0.5512 - val_accuracy: 0.8386
# Epoch 3/50
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.5218 - accuracy: 0.8453WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5218 - accuracy: 0.8454 - val_loss: 0.5289 - val_accuracy: 0.8430
# Epoch 4/50
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.5189 - accuracy: 0.8444WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5190 - accuracy: 0.8444 - val_loss: 0.5253 - val_accuracy: 0.8432
# Epoch 5/50
# 58880/60000 [============================>.] - ETA: 0s - loss: 0.5207 - accuracy: 0.8453WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5221 - accuracy: 0.8449 - val_loss: 0.5305 - val_accuracy: 0.8396
# Epoch 6/50
# 59136/60000 [============================>.] - ETA: 0s - loss: 0.5220 - accuracy: 0.8436WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.5216 - accuracy: 0.8438 - val_loss: 0.5168 - val_accuracy: 0.8472
# Epoch 7/50
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.5150 - accuracy: 0.8455WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.5149 - accuracy: 0.8455 - val_loss: 0.5127 - val_accuracy: 0.8462
# Epoch 8/50
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.5119 - accuracy: 0.8468WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5119 - accuracy: 0.8467 - val_loss: 0.5353 - val_accuracy: 0.8414
# Epoch 9/50
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.5039 - accuracy: 0.8496WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.5043 - accuracy: 0.8494 - val_loss: 0.5079 - val_accuracy: 0.8500
# Epoch 10/50
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.5125 - accuracy: 0.8460WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5126 - accuracy: 0.8459 - val_loss: 0.5075 - val_accuracy: 0.8536
# Epoch 11/50
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.5104 - accuracy: 0.8466WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.5105 - accuracy: 0.8465 - val_loss: 0.5261 - val_accuracy: 0.8452
# Epoch 12/50
# 59136/60000 [============================>.] - ETA: 0s - loss: 0.5074 - accuracy: 0.8493WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.5075 - accuracy: 0.8493 - val_loss: 0.5270 - val_accuracy: 0.8376
# Epoch 13/50
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.5085 - accuracy: 0.8476WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5084 - accuracy: 0.8477 - val_loss: 0.5090 - val_accuracy: 0.8474
# Epoch 00013: early stopping

# %%
model_best = Sequential()

model_best.add(Flatten(input_shape=(28, 28)))

model_best.add(Dense(128, activation='relu'))
model_best.add(Dropout(0.4))

model_best.add(Dense(64, activation='relu'))
model_best.add(Dropout(0.3))

model_best.add(Dense(32, activation='relu'))
model_best.add(Dropout(0.2))

model_best.add(Dense(10, activation='softmax'))

model_best.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# %%
EarlyStop = EarlyStopping(monitor='val_loss',
                          patience=5,
                          verbose=1)
model_check = ModelCheckpoint(filepath='Najlepszy model',
                              monitor='var_loss',
                              save_best_only=True)

# %%
best_history = model_best.fit(X_train,
                              y_train,
                              epochs=100,
                              verbose=1,
                              batch_size=2048,
                              validation_data=(X_val, y_val),
                              callbacks = [EarlyStop, model_check])
# Out:
# Train on 60000 samples, validate on 5000 samples
# Epoch 1/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 1.7379 - accuracy: 0.3715WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 2s 28us/sample - loss: 1.7336 - accuracy: 0.3729 - val_loss: 0.9733 - val_accuracy: 0.6488
# Epoch 2/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 1.0619 - accuracy: 0.6130WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 20us/sample - loss: 1.0605 - accuracy: 0.6136 - val_loss: 0.6977 - val_accuracy: 0.7572
# Epoch 3/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.8215 - accuracy: 0.7073WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.8206 - accuracy: 0.7076 - val_loss: 0.5830 - val_accuracy: 0.7950
# Epoch 4/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.7030 - accuracy: 0.7528WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.
ARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 17us/sample - loss: 0.3221 - accuracy: 0.8862 - val_loss: 0.3523 - val_accuracy: 0.8800
# Epoch 50/100
# 57344/60000 [===========================>..] - ETA: 0s - loss: 0.3213 - accuracy: 0.8876WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3215 - accuracy: 0.8875 - val_loss: 0.3515 - val_accuracy: 0.8804
# Epoch 51/100
# 57344/60000 [===========================>..] - ETA: 0s - loss: 0.3173 - accuracy: 0.8867WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3169 - accuracy: 0.8869 - val_loss: 0.3506 - val_accuracy: 0.8818
# Epoch 52/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3151 - accuracy: 0.8887WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3154 - accuracy: 0.8885 - val_loss: 0.3526 - val_accuracy: 0.8816
# Epoch 53/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3193 - accuracy: 0.8879WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3192 - accuracy: 0.8879 - val_loss: 0.3483 - val_accuracy: 0.8840
# Epoch 54/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3128 - accuracy: 0.8902WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 17us/sample - loss: 0.3126 - accuracy: 0.8901 - val_loss: 0.3542 - val_accuracy: 0.8808
# Epoch 55/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3119 - accuracy: 0.8905WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3117 - accuracy: 0.8907 - val_loss: 0.3506 - val_accuracy: 0.8826
# Epoch 56/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3088 - accuracy: 0.8899WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3091 - accuracy: 0.8900 - val_loss: 0.3515 - val_accuracy: 0.8800
# Epoch 57/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3066 - accuracy: 0.8910WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3070 - accuracy: 0.8909 - val_loss: 0.3481 - val_accuracy: 0.8836
# Epoch 58/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3072 - accuracy: 0.8913WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3068 - accuracy: 0.8915 - val_loss: 0.3542 - val_accuracy: 0.8814
# Epoch 59/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3089 - accuracy: 0.8909WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3086 - accuracy: 0.8909 - val_loss: 0.3495 - val_accuracy: 0.8812
# Epoch 60/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3045 - accuracy: 0.8922WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3047 - accuracy: 0.8921 - val_loss: 0.3486 - val_accuracy: 0.8854
# Epoch 61/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3092 - accuracy: 0.8906WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3087 - accuracy: 0.8906 - val_loss: 0.3502 - val_accuracy: 0.8808
# Epoch 62/100
# 59392/60000 [============================>.] - ETA: 0s - loss: 0.3036 - accuracy: 0.8924WARNING:tensorflow:Can save best model only with var_loss available, skipping.
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.3041 - accuracy: 0.8922 - val_loss: 0.3524 - val_accuracy: 0.8798
# Epoch 00062: early stopping

# %%
draw_curves(best_history, key1='accuracy', ylim1=(0.7, 0.95), key2='loss', ylim2=(0.0, 1.0))

# %%
y_train_pred = model.predict_classes(X_train) 
y_val_pred = model.predict_classes(X_val) 
y_test_pred = model.predict_classes(X_test)

# %%
def plot_value_img(i, predictions, true_label, img):
    predictions, true_label, img = predictions[i], true_label[i], img[i]    
    predicted_label = np.argmax(predictions)
    true_value = np.argmax(true_label)   
     
    plt.figure(figsize=(12,5))
     
    plt.subplot(1, 2, 1)
     
    plt.yticks(np.arange(len(class_names)), class_names)
    thisplot = plt.barh(range(10), predictions, color="gray")      
    thisplot[predicted_label].set_color('r')
    thisplot[true_value].set_color('g')
 
    plt.subplot(1, 2, 2) 
     
    plt.imshow(img, cmap=plt.cm.binary)
    if predicted_label == true_value:
        color = 'green'
    else:
        color = 'red'
 
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions),
                                class_names[true_value]),
                                color=color)    
    plt.show()
     
plot_value_img(1, y_val_pred,  y_val, X_val)
